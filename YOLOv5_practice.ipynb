# %% [markdown]
# # 使い方
# プログラムコードのあるセルを上から順に実行ボタンを押してプログラムを起動する
#
# ![yolo1.png](data:image/png;base64,...)

# %% [markdown]
# # yolo 初期設定

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12927, done.
# remote: Counting objects: 100% (309/309), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 12927 (delta 194), reused 265 (delta 162), pack-reused 12618
# Receiving objects: 100% (12927/12927), 12.67 MiB | 21.62 MiB/s, done.
# Resolving deltas: 100% (8846/8846), done.

# %%
# %pip install -qr yolov5/requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 4.2 MB/s

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %% [markdown]
# #推論

# %%
import os
from PIL import Image

# %% [markdown]
# ### 画像をアップロード
# ファイルタブに画像をドラッグ＆ドロップしてアップロード
#
# ①ファイルタブを開く
#
# ![yolo2.png](data:image/png;base64,...)
#
# ②ファイルをドラッグドロップする
# ![yolo3.png](data:image/png;base64,...)

# %%
# 推論する画像のファイル名を入力
img_name = 'cars.jpg'

# 画像を表示
target_img_name = '../' + img_name
img = Image.open(target_img_name)
display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### 推論

# %%
# !python detect.py --source {target_img_name} --name results --exist-ok
# Out:
# detect: weights=yolov5s.pt, source=../cars.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=results, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-394-gd7bc5d7 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 21.4MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/cars.jpg: 448x640 4 cars, 4 buss, 12 trucks, Done. (0.339s)
# Speed: 3.2ms pre-process, 339.2ms inference, 18.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/results

# %%
# 推論された画像を表示
img = Image.open("runs/detect/results/" + img_name)
display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
