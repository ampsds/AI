# %% [markdown]
# <a href="https://colab.research.google.com/github/ampsds/AI/blob/main/Whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q git+https://github.com/openai/whisper.git
# Out:
#      |████████████████████████████████| 4.9 MB 9.3 MB/s
#      |████████████████████████████████| 6.6 MB 52.6 MB/s
#      |████████████████████████████████| 120 kB 69.1 MB/s
# ...

# %%
# !wget -q https://soundeffect-lab.info/sound/voice/mp3/info-lady1/info-lady1-honzitsuhagoraizyou1.mp3

# %%
from IPython.display import Audio

AUDIO_PATH = "/content/info-lady1-honzitsuhagoraizyou1.mp3"

Audio(AUDIO_PATH)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import whisper

model = whisper.load_model("base")

# 音声データ読み込み & 30秒以内にカット
audio = whisper.load_audio(AUDIO_PATH)
audio = whisper.pad_or_trim(audio)

# ログメルスペクトログラムを作成 & モデルと同じデバイスに変換
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# 言語判定
_, probs = model.detect_language(mel)
print(f"言語判定: {max(probs, key=probs.get)}")

# 音声のデコード
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# 認識結果の出力
print(result.text)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 108MiB/s]
# 言語判定: ja
# 本日はご来場いただきまして 真ことにありがとうございます会延に先立ちましてお客様に お願い申し上げます携帯電話などおとの出るものの 電源はお切り下さいまた許可のない6音撮影はご演慮ください
